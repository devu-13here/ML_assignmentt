# %% [markdown]
# <a href="https://colab.research.google.com/github/devu-13here/ML_assignmentt/blob/main/Pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
df['Name']=['Devanjali','Sweet','Simran','Chetan','Sam','Mishi','Shubham','Aasma','Frosh','Ria']
df['age']=[10,40,89,89,89,67,67,89,35,67]
df['sex']=['F','F','M','M','M','M','M','F','F','M']
df
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df['age']>=89
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: age, dtype: bool

# %%
print(df[df['age']>=89])
# Out:
#      Name  age sex
# 2  Simran   89   M
# 3  Chetan   89   M
# 4     Sam   89   M
# 7   Aasma   89   F

# %%
df
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df[df['sex']=='F']
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 7      Aasma   89   F
# 8      Frosh   35   F

# %%
df.replace('F','Female')
# Out:
#         Name  age     sex
# 0  Devanjali   10  Female
# 1      Sweet   40  Female
# 2     Simran   89       M
# 3     Chetan   89       M
# 4        Sam   89       M
# 5      Mishi   67       M
# 6    Shubham   67       M
# 7      Aasma   89  Female
# 8      Frosh   35  Female
# 9        Ria   67       M

# %%
df.iloc[:]
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df.iloc[1:4]
# Out:
#      Name  age sex
# 1   Sweet   40   F
# 2  Simran   89   M
# 3  Chetan   89   M

# %%
df.rename(columns={'age':'Age'})
# Out:
#         Name  Age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df.rename(columns={'Name':'name'})
# Out:
#         name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
print(df[(df['sex']=='M') & (df['age']>=89)])
# Out:
#      Name  age sex
# 2  Simran   89   M
# 3  Chetan   89   M
# 4     Sam   89   M

# %%
print(df['sex'].unique())
# Out:
# ['F' 'M']

# %%
print(df['sex'].nunique())
# Out:
# 2

# %%
print(df['sex'].value_counts())
# Out:
# sex
# M    6
# F    4
# Name: count, dtype: int64

# %%
print(df['age'].mean())
# Out:
# 64.2

# %%
print(df['age'].max())
print(df['age'].min())
# Out:
# 89
# 10

# %%
print(df['age'].count())
# Out:
# 10

# %%
df.drop_duplicates()
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
#df.drop(['age'],axis=1)

# %%
df.drop(df.columns[1],axis=1)
# Out:
#         Name sex
# 0  Devanjali   F
# 1      Sweet   F
# 2     Simran   M
# 3     Chetan   M
# 4        Sam   M
# 5      Mishi   M
# 6    Shubham   M
# 7      Aasma   F
# 8      Frosh   F
# 9        Ria   M

# %%
df.drop_duplicates()
# Out:
#         Name  age sex
# 0  Devanjali   10   F
# 1      Sweet   40   F
# 2     Simran   89   M
# 3     Chetan   89   M
# 4        Sam   89   M
# 5      Mishi   67   M
# 6    Shubham   67   M
# 7      Aasma   89   F
# 8      Frosh   35   F
# 9        Ria   67   M

# %%
df.groupby('sex')

# %%
print(df.groupby('sex').sum())
# Out:
#                                Name  age
# sex
# F          DevanjaliSweetAasmaFrosh  174
# M    SimranChetanSamMishiShubhamRia  468

# %%
print(df.groupby('sex').sum())
# Out:
#                                Name  age
# sex
# F          DevanjaliSweetAasmaFrosh  174
# M    SimranChetanSamMishiShubhamRia  468

# %%
for name in df['Name']:
    print(name.upper())
# Out:
# DEVANJALI
# SWEET
# SIMRAN
# CHETAN
# SAM
# MISHI
# SHUBHAM
# AASMA
# FROSH
# RIA

# %%
df['age'].apply(lambda x:x*2)
# Out:
# 0     20
# 1     80
# 2    178
# 3    178
# 4    178
# 5    134
# 6    134
# 7    178
# 8     70
# 9    134
# Name: age, dtype: int64
